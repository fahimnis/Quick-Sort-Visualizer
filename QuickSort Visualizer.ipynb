# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import random
import math
from matplotlib import cm
# %matplotlib qt

# %%
#Taken from GeeksforGeeks

# This function takes last element as pivot, places 
# the pivot element at its correct position in sorted 
# array, and places all smaller (smaller than pivot) 
# to left of pivot and all greater elements to right 
# of pivot 
def partition(arr,low,high,n,color): 
    
    i = ( low-1 )         # index of smaller element 
    pivot = arr[high]     # pivot 
  
    for j in range(low , high): 
  
        # If current element is smaller than the pivot 
        if   arr[j] < pivot: 
          
            # increment index of smaller element 
            i = i+1 
            arr[i],arr[j] = arr[j],arr[i]
            frame = plt.imshow(np.reshape(arr,(n,n)),animated=True,cmap = color, alpha = 1)
            masterim.append([frame])
            
  
    arr[i+1],arr[high] = arr[high],arr[i+1] 
    
    frame = plt.imshow(np.reshape(arr,(n,n)),animated=True,cmap =color,alpha = 1)
    masterim.append([frame])
    
    return ( i+1 ) 
  
# The main function that implements QuickSort 
# arr[] --> Array to be sorted, 
# low  --> Starting index, 
# high  --> Ending index 
  
# Function to do Quick sort 
def quickSort(arr,low,high,n,color):
    '''
    Takes an array and sorts it based on the quick sort algorithm
    '''
    if low < high: 
  
        # pi is partitioning index, arr[p] is now 
        # at right place 
        pi = partition(arr,low,high,n,color) 
  
        # Separately sort elements before 
        # partition and after partition 
        quickSort(arr, low, pi-1,n,color) 
        quickSort(arr, pi+1, high,n,color) 
        
# # Driver code to test above 
# arr = [10, 7, 8, 9, 1, 5, 4, 3, 2] 
# n = len(arr) 
# quickSort(arr,0,n-1,3) 
# print ("Sorted array is:") 
# for i in range(n): 
#     print ("%d" %arr[i])

# %%
def viz_Qsort(ar):
    ''' 
    This funciton will take an N x M array and pass it to the  quickSort and then visualize the list of images which 
    are generated.
    
    '''
#     global ax
    
    fig,ax = plt.subplots(figsize=(8,7),facecolor='white',edgecolor = 'white');
    
    plt.title('Quick Sort Algorithm', pad = 15, fontdict = {'fontsize':35,'fontweight':30,'color':'purple'})

#     ax.text(2,15.5,'LOW VALUES',ha="center", va="center", color="darkred",size = 20)
#     ax.text(11.8,15.5,'HIGH VALUES',ha="center", va="center", color="darkblue",size = 20)
    
    l = len(ar);
    
    n = int(math.sqrt(l))

    
    global masterim
    
    masterim = [] 
    
    color = 'RdPu'  #inferno with yellow figure background looks crazyy!! 

    sort_array = quickSort(ar,0,l-1,n,color)
        
    ani = animation.ArtistAnimation(fig, masterim, interval=30, blit=True,
                                    repeat_delay=100);
    plt.axis('off')
    
#     plt.colorbar()
    
    writergif = animation.PillowWriter(fps=30) 

    ani.save('QSort3.gif', writer=writergif)
        
#     print(masterim)

# %%
arr = random.sample(range(0, 100), 100)

# viz_Qsort(arr)

# %%
arr
# Out:
# [78,
#  21,
#  68,
#  87,
#  26,
#  24,
#  59,
#  18,
#  60,
#  81,
#  55,
#  22,
#  74,
#  92,
#  29,
#  99,
#  45,
#  42,
#  39,
#  1,
#  58,
#  36,
#  83,
#  32,
#  65,
#  54,
#  96,
#  5,
#  73,
#  49,
#  82,
#  76,
#  84,
#  85,
#  50,
#  4,
#  43,
#  51,
#  41,
#  75,
#  80,
#  91,
#  48,
#  9,
#  20,
#  69,
#  66,
#  56,
#  40,
#  88,
#  67,
#  70,
#  79,
#  16,
#  7,
#  37,
#  38,
#  52,
#  13,
#  47,
#  10,
#  11,
#  23,
#  46,
#  33,
#  61,
#  97,
#  44,
#  72,
#  28,
#  53,
#  3,
#  62,
#  27,
#  15,
#  98,
#  63,
#  8,
#  57,
#  35,
#  64,
#  86,
#  31,
#  89,
#  93,
#  0,
#  6,
#  30,
#  14,
#  19,
#  77,
#  2,
#  95,
#  90,
#  12,
#  25,
#  17,
#  34,
#  71,
#  94]
